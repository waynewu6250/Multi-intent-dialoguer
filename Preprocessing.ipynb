# %% [markdown]
# # ATIS Dataset Exploration

# %%
import json
import pandas as pd
import numpy as np
with open('raw_datasets/ATIS/train.json', 'r') as f:
    data = json.load(f)

# %%
data['rasa_nlu_data']['common_examples']
# Out:
# [{'text': 'i want to fly from boston at 838 am and arrive in denver at 1110 in the morning',
#   'intent': 'flight',
#   'entities': [{'start': 19,
#     'end': 25,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 29, 'end': 35, 'value': '838 am', 'entity': 'depart_time.time'},
#    {'start': 50, 'end': 56, 'value': 'denver', 'entity': 'toloc.city_name'},
#    {'start': 60, 'end': 64, 'value': '1110', 'entity': 'arrive_time.time'},
#    {'start': 72,
#     'end': 79,
#     'value': 'morning',
#     'entity': 'arrive_time.period_of_day'}]},
#  {'text': 'what flights are available from pittsburgh to baltimore on thursday morning',
#   'intent': 'flight',
#   'entities': [{'start': 32,
#     'end': 42,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 46, 'end': 55, 'value': 'baltimore', 'entity': 'toloc.city_name'},
#    {'start': 59,
#     'end': 67,
#     'value': 'thursday',
#     'entity': 'depart_date.day_name'},
#    {'start': 68,
#     'end': 75,
#     'value': 'morning',
#     'entity': 'depart_time.period_of_day'}]},
#  {'text': 'what is the arrival time in san francisco for the 755 am flight leaving washington',
#   'intent': 'flight_time',
#   'entities': [{'start': 12,
#     'end': 24,
#     'value': 'arrival time',
#     'entity': 'flight_time'},
#    {'start': 28,
#     'end': 41,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 50, 'end': 56, 'value': '755 am', 'entity': 'depart_time.time'},
#    {'start': 72,
#     'end': 82,
#     'value': 'washington',
#     'entity': 'fromloc.city_name'}]},
#  {'text': 'cheapest airfare from tacoma to orlando',
#   'intent': 'airfare',
#   'entities': [{'start': 1,
#     'end': 9,
#     'value': 'cheapest',
#     'entity': 'cost_relative'},
#    {'start': 22, 'end': 28, 'value': 'tacoma', 'entity': 'fromloc.city_name'},
#    {'start': 32, 'end': 39, 'value': 'orlando', 'entity': 'toloc.city_name'}]},
#  {'text': 'round trip fares from pittsburgh to philadelphia under 1000 dollars',
#   'intent': 'airfare',
#   'entities': [{'start': 1,
#     'end': 11,
#     'value': 'round trip',
#     'entity': 'round_trip'},
#    {'start': 22,
#     'end': 32,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 36,
#     'end': 48,
#     'value': 'philadelphia',
#     'entity': 'toloc.city_name'},
#    {'start': 49, 'end': 54, 'value': 'under', 'entity': 'cost_relative'},
#    {'start': 55,
#     'end': 67,
#     'value': '1000 dollars',
#     'entity': 'fare_amount'}]},
#  {'text': 'i need a flight tomorrow from columbus to minneapolis',
#   'intent': 'flight',
#   'entities': [{'start': 16,
#     'end': 24,
#     'value': 'tomorrow',
#     'entity': 'depart_date.today_relative'},
#    {'start': 30,
#     'end': 38,
#     'value': 'columbus',
#     'entity': 'fromloc.city_name'},
#    {'start': 42,
#     'end': 53,
#     'value': 'minneapolis',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what kind of aircraft is used on a flight from cleveland to dallas',
#   'intent': 'aircraft',
#   'entities': [{'start': 47,
#     'end': 56,
#     'value': 'cleveland',
#     'entity': 'fromloc.city_name'},
#    {'start': 60, 'end': 66, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': 'show me the flights from pittsburgh to los angeles on thursday',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 35,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 39,
#     'end': 50,
#     'value': 'los angeles',
#     'entity': 'toloc.city_name'},
#    {'start': 54,
#     'end': 62,
#     'value': 'thursday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'all flights from boston to washington',
#   'intent': 'flight',
#   'entities': [{'start': 17,
#     'end': 23,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 27,
#     'end': 37,
#     'value': 'washington',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what kind of ground transportation is available in denver',
#   'intent': 'ground_service',
#   'entities': [{'start': 51,
#     'end': 57,
#     'value': 'denver',
#     'entity': 'city_name'}]},
#  {'text': 'show me the flights from dallas to san francisco',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'dallas',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 48,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'show me the flights from san diego to newark by way of houston',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 34,
#     'value': 'san diego',
#     'entity': 'fromloc.city_name'},
#    {'start': 38, 'end': 44, 'value': 'newark', 'entity': 'toloc.city_name'},
#    {'start': 55,
#     'end': 62,
#     'value': 'houston',
#     'entity': 'stoploc.city_name'}]},
#  {'text': "what 's the airport at orlando",
#   'intent': 'airport',
#   'entities': [{'start': 23,
#     'end': 30,
#     'value': 'orlando',
#     'entity': 'city_name'}]},
#  {'text': 'what is the cheapest flight from boston to bwi',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'cheapest',
#     'entity': 'cost_relative'},
#    {'start': 33, 'end': 39, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 43, 'end': 46, 'value': 'bwi', 'entity': 'toloc.airport_code'}]},
#  {'text': 'all flights to baltimore after 6 pm',
#   'intent': 'flight',
#   'entities': [{'start': 15,
#     'end': 24,
#     'value': 'baltimore',
#     'entity': 'toloc.city_name'},
#    {'start': 25,
#     'end': 30,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 31, 'end': 35, 'value': '6 pm', 'entity': 'depart_time.time'}]},
#  {'text': 'show me the first class fares from boston to denver',
#   'intent': 'airfare',
#   'entities': [{'start': 12,
#     'end': 23,
#     'value': 'first class',
#     'entity': 'class_type'},
#    {'start': 35, 'end': 41, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 45, 'end': 51, 'value': 'denver', 'entity': 'toloc.city_name'}]},
#  {'text': 'show me the ground transportation in denver',
#   'intent': 'ground_service',
#   'entities': [{'start': 37,
#     'end': 43,
#     'value': 'denver',
#     'entity': 'city_name'}]},
#  {'text': 'all flights from denver to pittsburgh leaving after 6 pm and before 7 pm',
#   'intent': 'flight',
#   'entities': [{'start': 17,
#     'end': 23,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 27,
#     'end': 37,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 46,
#     'end': 51,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 52, 'end': 56, 'value': '6 pm', 'entity': 'depart_time.time'},
#    {'start': 61,
#     'end': 67,
#     'value': 'before',
#     'entity': 'depart_time.time_relative'},
#    {'start': 68, 'end': 72, 'value': '7 pm', 'entity': 'depart_time.time'}]},
#  {'text': 'i need information on flights for tuesday leaving baltimore for dallas dallas to boston and boston to baltimore',
#   'intent': 'flight',
#   'entities': [{'start': 34,
#     'end': 41,
#     'value': 'tuesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 50,
#     'end': 59,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 64, 'end': 70, 'value': 'dallas', 'entity': 'toloc.city_name'},
#    {'start': 71, 'end': 77, 'value': 'dallas', 'entity': 'fromloc.city_name'},
#    {'start': 81, 'end': 87, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 92, 'end': 98, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 102,
#     'end': 111,
#     'value': 'baltimore',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'please give me the flights from boston to pittsburgh on thursday of next week',
#   'intent': 'flight',
#   'entities': [{'start': 32,
#     'end': 38,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 42,
#     'end': 52,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 56,
#     'end': 64,
#     'value': 'thursday',
#     'entity': 'depart_date.day_name'},
#    {'start': 68,
#     'end': 72,
#     'value': 'next',
#     'entity': 'depart_date.date_relative'}]},
#  {'text': 'i would like to fly from denver to pittsburgh on united airlines',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 45,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 49,
#     'end': 64,
#     'value': 'united airlines',
#     'entity': 'airline_name'}]},
#  {'text': 'show me the flights from san diego to newark',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 34,
#     'value': 'san diego',
#     'entity': 'fromloc.city_name'},
#    {'start': 38, 'end': 44, 'value': 'newark', 'entity': 'toloc.city_name'}]},
#  {'text': 'please list all first class flights on united from denver to baltimore',
#   'intent': 'flight',
#   'entities': [{'start': 16,
#     'end': 27,
#     'value': 'first class',
#     'entity': 'class_type'},
#    {'start': 39, 'end': 45, 'value': 'united', 'entity': 'airline_name'},
#    {'start': 51, 'end': 57, 'value': 'denver', 'entity': 'fromloc.city_name'},
#    {'start': 61,
#     'end': 70,
#     'value': 'baltimore',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what kinds of planes are used by american airlines',
#   'intent': 'aircraft',
#   'entities': [{'start': 33,
#     'end': 50,
#     'value': 'american airlines',
#     'entity': 'airline_name'}]},
#  {'text': "i 'd like to have some information on a ticket from denver to pittsburgh and atlanta",
#   'intent': 'airfare',
#   'entities': [{'start': 52,
#     'end': 58,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 62,
#     'end': 72,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 77, 'end': 84, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': "i 'd like to book a flight from atlanta to denver",
#   'intent': 'flight',
#   'entities': [{'start': 32,
#     'end': 39,
#     'value': 'atlanta',
#     'entity': 'fromloc.city_name'},
#    {'start': 43, 'end': 49, 'value': 'denver', 'entity': 'toloc.city_name'}]},
#  {'text': 'which airline serves denver pittsburgh and atlanta',
#   'intent': 'airline',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 28,
#     'end': 38,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 43,
#     'end': 50,
#     'value': 'atlanta',
#     'entity': 'fromloc.city_name'}]},
#  {'text': "show me all flights from boston to pittsburgh on wednesday of next week which leave boston after 2 o'clock pm",
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 45,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 49,
#     'end': 58,
#     'value': 'wednesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 62,
#     'end': 66,
#     'value': 'next',
#     'entity': 'depart_date.date_relative'},
#    {'start': 84, 'end': 90, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 91,
#     'end': 96,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 97,
#     'end': 109,
#     'value': "2 o'clock pm",
#     'entity': 'depart_time.time'}]},
#  {'text': 'atlanta ground transportation',
#   'intent': 'ground_service',
#   'entities': [{'start': 1,
#     'end': 8,
#     'value': 'atlanta',
#     'entity': 'city_name'}]},
#  {'text': 'i also need service from dallas to boston arriving by noon',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'dallas',
#     'entity': 'fromloc.city_name'},
#    {'start': 35, 'end': 41, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 51,
#     'end': 53,
#     'value': 'by',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 54, 'end': 58, 'value': 'noon', 'entity': 'arrive_time.time'}]},
#  {'text': 'show me the cheapest round trip fare from baltimore to dallas',
#   'intent': 'airfare',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'cheapest',
#     'entity': 'cost_relative'},
#    {'start': 21, 'end': 31, 'value': 'round trip', 'entity': 'round_trip'},
#    {'start': 42,
#     'end': 51,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 55, 'end': 61, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': 'show me all flights from new york to milwaukee on northwest airlines departing at 720 am',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 33,
#     'value': 'new york',
#     'entity': 'fromloc.city_name'},
#    {'start': 37, 'end': 46, 'value': 'milwaukee', 'entity': 'toloc.city_name'},
#    {'start': 50,
#     'end': 68,
#     'value': 'northwest airlines',
#     'entity': 'airline_name'},
#    {'start': 82, 'end': 88, 'value': '720 am', 'entity': 'depart_time.time'}]},
#  {'text': 'flights from new york to miami',
#   'intent': 'flight',
#   'entities': [{'start': 13,
#     'end': 21,
#     'value': 'new york',
#     'entity': 'fromloc.city_name'},
#    {'start': 25, 'end': 30, 'value': 'miami', 'entity': 'toloc.city_name'}]},
#  {'text': 'please find a flight on delta from philadelphia to san francisco and give me the flight numbers',
#   'intent': 'flight',
#   'entities': [{'start': 24,
#     'end': 29,
#     'value': 'delta',
#     'entity': 'airline_name'},
#    {'start': 35,
#     'end': 47,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 51,
#     'end': 64,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'i need a flight from dallas to san francisco',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'dallas',
#     'entity': 'fromloc.city_name'},
#    {'start': 31,
#     'end': 44,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'fares and flights from pittsburgh to philadelphia',
#   'intent': 'airfare',
#   'entities': [{'start': 23,
#     'end': 33,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 37,
#     'end': 49,
#     'value': 'philadelphia',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'show me the airlines with first class flights',
#   'intent': 'airline',
#   'entities': [{'start': 26,
#     'end': 37,
#     'value': 'first class',
#     'entity': 'class_type'}]},
#  {'text': 'what are the flights from st. louis to burbank sunday evening',
#   'intent': 'flight',
#   'entities': [{'start': 26,
#     'end': 35,
#     'value': 'st. louis',
#     'entity': 'fromloc.city_name'},
#    {'start': 39, 'end': 46, 'value': 'burbank', 'entity': 'toloc.city_name'},
#    {'start': 47,
#     'end': 53,
#     'value': 'sunday',
#     'entity': 'depart_date.day_name'},
#    {'start': 54,
#     'end': 61,
#     'value': 'evening',
#     'entity': 'depart_time.period_of_day'}]},
#  {'text': "i 'd like to arrange a flight from pittsburgh to atlanta",
#   'intent': 'flight',
#   'entities': [{'start': 35,
#     'end': 45,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 49, 'end': 56, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'show flights from baltimore to san francisco between 6 pm and 8 pm on friday',
#   'intent': 'flight',
#   'entities': [{'start': 18,
#     'end': 27,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 31,
#     'end': 44,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 53,
#     'end': 57,
#     'value': '6 pm',
#     'entity': 'depart_time.start_time'},
#    {'start': 62, 'end': 66, 'value': '8 pm', 'entity': 'depart_time.end_time'},
#    {'start': 70,
#     'end': 76,
#     'value': 'friday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'how far is it from orlando airport to orlando',
#   'intent': 'distance',
#   'entities': [{'start': 19,
#     'end': 34,
#     'value': 'orlando airport',
#     'entity': 'fromloc.airport_name'},
#    {'start': 38, 'end': 45, 'value': 'orlando', 'entity': 'toloc.city_name'}]},
#  {'text': 'i would like a list of round trip flights between indianapolis and orlando florida for the twenty seventh and the twenty eighth of december',
#   'intent': 'flight',
#   'entities': [{'start': 23,
#     'end': 33,
#     'value': 'round trip',
#     'entity': 'round_trip'},
#    {'start': 50,
#     'end': 62,
#     'value': 'indianapolis',
#     'entity': 'fromloc.city_name'},
#    {'start': 67, 'end': 74, 'value': 'orlando', 'entity': 'toloc.city_name'},
#    {'start': 75, 'end': 82, 'value': 'florida', 'entity': 'toloc.state_name'},
#    {'start': 91,
#     'end': 105,
#     'value': 'twenty seventh',
#     'entity': 'depart_date.day_number'},
#    {'start': 114,
#     'end': 127,
#     'value': 'twenty eighth',
#     'entity': 'depart_date.day_number'},
#    {'start': 131,
#     'end': 139,
#     'value': 'december',
#     'entity': 'depart_date.month_name'}]},
#  {'text': 'which airline has the most arrivals in atlanta',
#   'intent': 'airline',
#   'entities': [{'start': 22, 'end': 26, 'value': 'most', 'entity': 'mod'},
#    {'start': 39, 'end': 46, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'what airlines fly from new york to milwaukee to los angeles',
#   'intent': 'airline',
#   'entities': [{'start': 23,
#     'end': 31,
#     'value': 'new york',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 44,
#     'value': 'milwaukee',
#     'entity': 'stoploc.city_name'},
#    {'start': 48,
#     'end': 59,
#     'value': 'los angeles',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'pittsburgh to denver',
#   'intent': 'flight',
#   'entities': [{'start': 1,
#     'end': 11,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 14, 'end': 20, 'value': 'denver', 'entity': 'toloc.city_name'}]},
#  {'text': 'which airlines serve atlanta',
#   'intent': 'airline',
#   'entities': [{'start': 21,
#     'end': 28,
#     'value': 'atlanta',
#     'entity': 'city_name'}]},
#  {'text': 'show me information on ground transportation for dallas',
#   'intent': 'ground_service',
#   'entities': [{'start': 49,
#     'end': 55,
#     'value': 'dallas',
#     'entity': 'city_name'}]},
#  {'text': 'what is fare code h',
#   'intent': 'abbreviation',
#   'entities': [{'start': 18,
#     'end': 19,
#     'value': 'h',
#     'entity': 'fare_basis_code'}]},
#  {'text': 'show me all flights from boston to dallas fort worth both direct and connecting that arrive before noon',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 52,
#     'value': 'dallas fort worth',
#     'entity': 'toloc.city_name'},
#    {'start': 92,
#     'end': 98,
#     'value': 'before',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 99, 'end': 103, 'value': 'noon', 'entity': 'arrive_time.time'}]},
#  {'text': 'i need a flight from charlotte to newark leaving today evening',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 30,
#     'value': 'charlotte',
#     'entity': 'fromloc.city_name'},
#    {'start': 34, 'end': 40, 'value': 'newark', 'entity': 'toloc.city_name'},
#    {'start': 49,
#     'end': 54,
#     'value': 'today',
#     'entity': 'depart_date.today_relative'},
#    {'start': 55,
#     'end': 62,
#     'value': 'evening',
#     'entity': 'depart_time.period_of_day'}]},
#  {'text': 'what are the times that you have planes leaving from san francisco going to pittsburgh on july seventh',
#   'intent': 'flight_time',
#   'entities': [{'start': 13,
#     'end': 18,
#     'value': 'times',
#     'entity': 'flight_time'},
#    {'start': 53,
#     'end': 66,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 76,
#     'end': 86,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 90,
#     'end': 94,
#     'value': 'july',
#     'entity': 'depart_date.month_name'},
#    {'start': 95,
#     'end': 102,
#     'value': 'seventh',
#     'entity': 'depart_date.day_number'}]},
#  {'text': 'flights from newark to cleveland',
#   'intent': 'flight',
#   'entities': [{'start': 13,
#     'end': 19,
#     'value': 'newark',
#     'entity': 'fromloc.city_name'},
#    {'start': 23,
#     'end': 32,
#     'value': 'cleveland',
#     'entity': 'toloc.city_name'}]},
#  {'text': "what flights go from boston to pittsburgh after 6 o'clock next tuesday",
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 31,
#     'end': 41,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 42,
#     'end': 47,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 48,
#     'end': 57,
#     'value': "6 o'clock",
#     'entity': 'depart_time.time'},
#    {'start': 58,
#     'end': 62,
#     'value': 'next',
#     'entity': 'depart_date.date_relative'},
#    {'start': 63,
#     'end': 70,
#     'value': 'tuesday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'how much does the limousine service cost within pittsburgh',
#   'intent': 'ground_fare',
#   'entities': [{'start': 18,
#     'end': 27,
#     'value': 'limousine',
#     'entity': 'transport_type'},
#    {'start': 48, 'end': 58, 'value': 'pittsburgh', 'entity': 'city_name'}]},
#  {'text': 'does us air have any flights out of atlanta to denver',
#   'intent': 'flight',
#   'entities': [{'start': 5,
#     'end': 11,
#     'value': 'us air',
#     'entity': 'airline_name'},
#    {'start': 36, 'end': 43, 'value': 'atlanta', 'entity': 'fromloc.city_name'},
#    {'start': 47, 'end': 53, 'value': 'denver', 'entity': 'toloc.city_name'}]},
#  {'text': 'what is booking class c',
#   'intent': 'abbreviation',
#   'entities': [{'start': 22,
#     'end': 23,
#     'value': 'c',
#     'entity': 'fare_basis_code'}]},
#  {'text': "i 'd like to know the shortest trip between boston and san francisco",
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 30,
#     'value': 'shortest',
#     'entity': 'flight_mod'},
#    {'start': 44, 'end': 50, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 55,
#     'end': 68,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'i would like to see information for flights from san francisco leaving after 12 pm to pittsburgh on monday',
#   'intent': 'flight',
#   'entities': [{'start': 49,
#     'end': 62,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 71,
#     'end': 76,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 77, 'end': 82, 'value': '12 pm', 'entity': 'depart_time.time'},
#    {'start': 86,
#     'end': 96,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 100,
#     'end': 106,
#     'value': 'monday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'what is the least expensive flight from denver to atlanta',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 27,
#     'value': 'least expensive',
#     'entity': 'cost_relative'},
#    {'start': 40, 'end': 46, 'value': 'denver', 'entity': 'fromloc.city_name'},
#    {'start': 50, 'end': 57, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'i need to know information for flights leaving dallas on tuesday evening and returning to atlanta',
#   'intent': 'flight',
#   'entities': [{'start': 47,
#     'end': 53,
#     'value': 'dallas',
#     'entity': 'fromloc.city_name'},
#    {'start': 57,
#     'end': 64,
#     'value': 'tuesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 65,
#     'end': 72,
#     'value': 'evening',
#     'entity': 'depart_time.period_of_day'},
#    {'start': 90, 'end': 97, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'what flight goes from denver to baltimore first class on united airlines arriving on may seventh',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 28,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 32, 'end': 41, 'value': 'baltimore', 'entity': 'toloc.city_name'},
#    {'start': 42, 'end': 53, 'value': 'first class', 'entity': 'class_type'},
#    {'start': 57,
#     'end': 72,
#     'value': 'united airlines',
#     'entity': 'airline_name'},
#    {'start': 85,
#     'end': 88,
#     'value': 'may',
#     'entity': 'arrive_date.month_name'},
#    {'start': 89,
#     'end': 96,
#     'value': 'seventh',
#     'entity': 'arrive_date.day_number'}]},
#  {'text': 'could you please tell me the airlines that fly from toronto to san diego',
#   'intent': 'airline',
#   'entities': [{'start': 52,
#     'end': 59,
#     'value': 'toronto',
#     'entity': 'fromloc.city_name'},
#    {'start': 63,
#     'end': 72,
#     'value': 'san diego',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what flights do you have from burbank to tacoma washington',
#   'intent': 'flight',
#   'entities': [{'start': 30,
#     'end': 37,
#     'value': 'burbank',
#     'entity': 'fromloc.city_name'},
#    {'start': 41, 'end': 47, 'value': 'tacoma', 'entity': 'toloc.city_name'},
#    {'start': 48,
#     'end': 58,
#     'value': 'washington',
#     'entity': 'toloc.state_name'}]},
#  {'text': 'what is the ground transportation from philadelphia airport to the city proper',
#   'intent': 'ground_service',
#   'entities': [{'start': 39,
#     'end': 59,
#     'value': 'philadelphia airport',
#     'entity': 'fromloc.airport_name'}]},
#  {'text': 'which airlines have first class flights today',
#   'intent': 'airline',
#   'entities': [{'start': 20,
#     'end': 31,
#     'value': 'first class',
#     'entity': 'class_type'},
#    {'start': 40,
#     'end': 45,
#     'value': 'today',
#     'entity': 'depart_date.today_relative'}]},
#  {'text': 'find the latest flight from san francisco to atlanta that serves a meal',
#   'intent': 'flight',
#   'entities': [{'start': 9,
#     'end': 15,
#     'value': 'latest',
#     'entity': 'flight_mod'},
#    {'start': 28,
#     'end': 41,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 45, 'end': 52, 'value': 'atlanta', 'entity': 'toloc.city_name'},
#    {'start': 67, 'end': 71, 'value': 'meal', 'entity': 'meal'}]},
#  {'text': 'i would like to make a reservation for a flight to denver from philadelphia on this coming sunday',
#   'intent': 'flight',
#   'entities': [{'start': 51,
#     'end': 57,
#     'value': 'denver',
#     'entity': 'toloc.city_name'},
#    {'start': 63,
#     'end': 75,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 79,
#     'end': 83,
#     'value': 'this',
#     'entity': 'depart_date.date_relative'},
#    {'start': 91,
#     'end': 97,
#     'value': 'sunday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'give me a list of airports in baltimore',
#   'intent': 'airport',
#   'entities': [{'start': 30,
#     'end': 39,
#     'value': 'baltimore',
#     'entity': 'city_name'}]},
#  {'text': 'show me flights from boston to denver on wednesday',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 31, 'end': 37, 'value': 'denver', 'entity': 'toloc.city_name'},
#    {'start': 41,
#     'end': 50,
#     'value': 'wednesday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'show me the flights from boston to baltimore',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 44,
#     'value': 'baltimore',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what does fare code q mean',
#   'intent': 'abbreviation',
#   'entities': [{'start': 20,
#     'end': 21,
#     'value': 'q',
#     'entity': 'fare_basis_code'}]},
#  {'text': 'please give me the flights from san francisco to washington dc',
#   'intent': 'flight',
#   'entities': [{'start': 32,
#     'end': 45,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 49,
#     'end': 59,
#     'value': 'washington',
#     'entity': 'toloc.city_name'},
#    {'start': 60, 'end': 62, 'value': 'dc', 'entity': 'toloc.state_code'}]},
#  {'text': 'i need information from denver to pittsburgh',
#   'intent': 'flight',
#   'entities': [{'start': 24,
#     'end': 30,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 34,
#     'end': 44,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'from seattle to salt lake city',
#   'intent': 'flight',
#   'entities': [{'start': 5,
#     'end': 12,
#     'value': 'seattle',
#     'entity': 'fromloc.city_name'},
#    {'start': 16,
#     'end': 30,
#     'value': 'salt lake city',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what is the earliest flight from boston to bwi that serves a snack',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'earliest',
#     'entity': 'flight_mod'},
#    {'start': 33, 'end': 39, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 43, 'end': 46, 'value': 'bwi', 'entity': 'toloc.airport_code'},
#    {'start': 61, 'end': 66, 'value': 'snack', 'entity': 'meal_description'}]},
#  {'text': 'what types of aircraft does delta fly',
#   'intent': 'aircraft',
#   'entities': [{'start': 28,
#     'end': 33,
#     'value': 'delta',
#     'entity': 'airline_name'}]},
#  {'text': 'what is the cost of a round trip flight from pittsburgh to atlanta beginning on april twenty fifth and returning on may sixth',
#   'intent': 'airfare',
#   'entities': [{'start': 22,
#     'end': 32,
#     'value': 'round trip',
#     'entity': 'round_trip'},
#    {'start': 45,
#     'end': 55,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 59, 'end': 66, 'value': 'atlanta', 'entity': 'toloc.city_name'},
#    {'start': 80,
#     'end': 85,
#     'value': 'april',
#     'entity': 'depart_date.month_name'},
#    {'start': 86,
#     'end': 98,
#     'value': 'twenty fifth',
#     'entity': 'depart_date.day_number'},
#    {'start': 116,
#     'end': 119,
#     'value': 'may',
#     'entity': 'return_date.month_name'},
#    {'start': 120,
#     'end': 125,
#     'value': 'sixth',
#     'entity': 'return_date.day_number'}]},
#  {'text': 'give me the flights leaving denver august ninth coming back to boston',
#   'intent': 'flight',
#   'entities': [{'start': 28,
#     'end': 34,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 41,
#     'value': 'august',
#     'entity': 'depart_date.month_name'},
#    {'start': 42,
#     'end': 47,
#     'value': 'ninth',
#     'entity': 'depart_date.day_number'},
#    {'start': 63, 'end': 69, 'value': 'boston', 'entity': 'toloc.city_name'}]},
#  {'text': 'list all the flights that fly into general mitchell international',
#   'intent': 'flight',
#   'entities': [{'start': 35,
#     'end': 65,
#     'value': 'general mitchell international',
#     'entity': 'fromloc.airport_name'}]},
#  {'text': 'what flights fly from denver to san francisco on monday tuesday wednesday thursday and friday',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 28,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 32,
#     'end': 45,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 49,
#     'end': 55,
#     'value': 'monday',
#     'entity': 'depart_date.day_name'},
#    {'start': 56,
#     'end': 63,
#     'value': 'tuesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 64,
#     'end': 73,
#     'value': 'wednesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 74,
#     'end': 82,
#     'value': 'thursday',
#     'entity': 'depart_date.day_name'},
#    {'start': 87,
#     'end': 93,
#     'value': 'friday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'list all flights from indianapolis to seattle',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 34,
#     'value': 'indianapolis',
#     'entity': 'fromloc.city_name'},
#    {'start': 38, 'end': 45, 'value': 'seattle', 'entity': 'toloc.city_name'}]},
#  {'text': 'in flight meal oakland to philadelphia saturday',
#   'intent': 'flight',
#   'entities': [{'start': 10, 'end': 14, 'value': 'meal', 'entity': 'meal'},
#    {'start': 15, 'end': 22, 'value': 'oakland', 'entity': 'fromloc.city_name'},
#    {'start': 26,
#     'end': 38,
#     'value': 'philadelphia',
#     'entity': 'toloc.city_name'},
#    {'start': 39,
#     'end': 47,
#     'value': 'saturday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'show me the flights on twa from atlanta in the morning',
#   'intent': 'flight',
#   'entities': [{'start': 23,
#     'end': 26,
#     'value': 'twa',
#     'entity': 'airline_code'},
#    {'start': 32, 'end': 39, 'value': 'atlanta', 'entity': 'fromloc.city_name'},
#    {'start': 47,
#     'end': 54,
#     'value': 'morning',
#     'entity': 'depart_time.period_of_day'}]},
#  {'text': 'i want to find the first flight from baltimore to boston that serves a meal',
#   'intent': 'flight',
#   'entities': [{'start': 19,
#     'end': 24,
#     'value': 'first',
#     'entity': 'flight_mod'},
#    {'start': 37,
#     'end': 46,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 50, 'end': 56, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 71, 'end': 75, 'value': 'meal', 'entity': 'meal'}]},
#  {'text': 'of all airlines which airline has the most arrivals in atlanta',
#   'intent': 'airline',
#   'entities': [{'start': 38, 'end': 42, 'value': 'most', 'entity': 'mod'},
#    {'start': 55, 'end': 62, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'display all flights from baltimore to boston on july twenty ninth',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 34,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 38, 'end': 44, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 48,
#     'end': 52,
#     'value': 'july',
#     'entity': 'depart_date.month_name'},
#    {'start': 53,
#     'end': 65,
#     'value': 'twenty ninth',
#     'entity': 'depart_date.day_number'}]},
#  {'text': 'i want to travel from atlanta to baltimore early in the morning first flight',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 29,
#     'value': 'atlanta',
#     'entity': 'fromloc.city_name'},
#    {'start': 33, 'end': 42, 'value': 'baltimore', 'entity': 'toloc.city_name'},
#    {'start': 43,
#     'end': 48,
#     'value': 'early',
#     'entity': 'depart_time.period_mod'},
#    {'start': 56,
#     'end': 63,
#     'value': 'morning',
#     'entity': 'depart_time.period_of_day'},
#    {'start': 64, 'end': 69, 'value': 'first', 'entity': 'flight_mod'}]},
#  {'text': 'i now need a flight from san jose to houston leaving on sunday the fourth',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 33,
#     'value': 'san jose',
#     'entity': 'fromloc.city_name'},
#    {'start': 37, 'end': 44, 'value': 'houston', 'entity': 'toloc.city_name'},
#    {'start': 56,
#     'end': 62,
#     'value': 'sunday',
#     'entity': 'depart_date.day_name'},
#    {'start': 67,
#     'end': 73,
#     'value': 'fourth',
#     'entity': 'depart_date.day_number'}]},
#  {'text': 'what are the flights available after 6 pm between san francisco and boston',
#   'intent': 'flight',
#   'entities': [{'start': 31,
#     'end': 36,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 37, 'end': 41, 'value': '6 pm', 'entity': 'depart_time.time'},
#    {'start': 50,
#     'end': 63,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 68, 'end': 74, 'value': 'boston', 'entity': 'toloc.city_name'}]},
#  {'text': 'what flights depart baltimore on friday and arrive in san francisco by 8 pm',
#   'intent': 'flight',
#   'entities': [{'start': 20,
#     'end': 29,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 33,
#     'end': 39,
#     'value': 'friday',
#     'entity': 'depart_date.day_name'},
#    {'start': 54,
#     'end': 67,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 68,
#     'end': 70,
#     'value': 'by',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 71, 'end': 75, 'value': '8 pm', 'entity': 'arrive_time.time'}]},
#  {'text': 'show me flights from boston to san francisco',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 31,
#     'end': 44,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'list the delta airlines flights from boston to philadelphia',
#   'intent': 'flight',
#   'entities': [{'start': 9,
#     'end': 23,
#     'value': 'delta airlines',
#     'entity': 'airline_name'},
#    {'start': 37, 'end': 43, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 47,
#     'end': 59,
#     'value': 'philadelphia',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'show me the fares from dallas to san francisco',
#   'intent': 'airfare',
#   'entities': [{'start': 23,
#     'end': 29,
#     'value': 'dallas',
#     'entity': 'fromloc.city_name'},
#    {'start': 33,
#     'end': 46,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': "what nonstop flights between boston and washington arrive after 4 o'clock pm",
#   'intent': 'flight',
#   'entities': [{'start': 5,
#     'end': 12,
#     'value': 'nonstop',
#     'entity': 'flight_stop'},
#    {'start': 29, 'end': 35, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 40,
#     'end': 50,
#     'value': 'washington',
#     'entity': 'toloc.city_name'},
#    {'start': 58,
#     'end': 63,
#     'value': 'after',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 64,
#     'end': 76,
#     'value': "4 o'clock pm",
#     'entity': 'arrive_time.time'}]},
#  {'text': 'what is the distance from los angeles international airport to los angeles',
#   'intent': 'distance',
#   'entities': [{'start': 26,
#     'end': 59,
#     'value': 'los angeles international airport',
#     'entity': 'fromloc.airport_name'},
#    {'start': 63,
#     'end': 74,
#     'value': 'los angeles',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'ground transportation in san jose',
#   'intent': 'ground_service',
#   'entities': [{'start': 25,
#     'end': 33,
#     'value': 'san jose',
#     'entity': 'city_name'}]},
#  {'text': 'please tell me how many nonstop flights there are from boston to atlanta',
#   'intent': 'quantity',
#   'entities': [{'start': 24,
#     'end': 31,
#     'value': 'nonstop',
#     'entity': 'flight_stop'},
#    {'start': 55, 'end': 61, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 65, 'end': 72, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'on the earliest flight from san francisco to atlanta on delta is a meal being served',
#   'intent': 'flight',
#   'entities': [{'start': 7,
#     'end': 15,
#     'value': 'earliest',
#     'entity': 'flight_mod'},
#    {'start': 28,
#     'end': 41,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 45, 'end': 52, 'value': 'atlanta', 'entity': 'toloc.city_name'},
#    {'start': 56, 'end': 61, 'value': 'delta', 'entity': 'airline_name'},
#    {'start': 67, 'end': 71, 'value': 'meal', 'entity': 'meal'}]},
#  {'text': 'where does canadian airlines international fly',
#   'intent': 'flight',
#   'entities': [{'start': 11,
#     'end': 42,
#     'value': 'canadian airlines international',
#     'entity': 'airline_name'}]},
#  {'text': 'what flights from denver to pittsburgh arrive before 8 in the morning',
#   'intent': 'flight',
#   'entities': [{'start': 18,
#     'end': 24,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 28,
#     'end': 38,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 46,
#     'end': 52,
#     'value': 'before',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 53, 'end': 54, 'value': '8', 'entity': 'arrive_time.time'},
#    {'start': 62,
#     'end': 69,
#     'value': 'morning',
#     'entity': 'arrive_time.period_of_day'}]},
#  {'text': 'find me the earliest flight from boston to atlanta',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'earliest',
#     'entity': 'flight_mod'},
#    {'start': 33, 'end': 39, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 43, 'end': 50, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': 'list nonstop flights from houston to dallas which arrive before midnight',
#   'intent': 'flight',
#   'entities': [{'start': 5,
#     'end': 12,
#     'value': 'nonstop',
#     'entity': 'flight_stop'},
#    {'start': 26, 'end': 33, 'value': 'houston', 'entity': 'fromloc.city_name'},
#    {'start': 37, 'end': 43, 'value': 'dallas', 'entity': 'toloc.city_name'},
#    {'start': 57,
#     'end': 63,
#     'value': 'before',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 64,
#     'end': 72,
#     'value': 'midnight',
#     'entity': 'arrive_time.period_of_day'}]},
#  {'text': 'show me the flights from boston to san francisco that stop in atlanta',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 31,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 35,
#     'end': 48,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 62,
#     'end': 69,
#     'value': 'atlanta',
#     'entity': 'stoploc.city_name'}]},
#  {'text': 'show me flights to san francisco from philadelphia stopping in dallas',
#   'intent': 'flight',
#   'entities': [{'start': 19,
#     'end': 32,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 38,
#     'end': 50,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 63,
#     'end': 69,
#     'value': 'dallas',
#     'entity': 'stoploc.city_name'}]},
#  {'text': 'what city is the airport mco in',
#   'intent': 'city',
#   'entities': [{'start': 25,
#     'end': 28,
#     'value': 'mco',
#     'entity': 'fromloc.airport_code'}]},
#  {'text': 'how much does it cost to rent a car in tacoma',
#   'intent': 'ground_fare',
#   'entities': [{'start': 32,
#     'end': 35,
#     'value': 'car',
#     'entity': 'transport_type'},
#    {'start': 39, 'end': 45, 'value': 'tacoma', 'entity': 'city_name'}]},
#  {'text': 'show me flights from baltimore to dallas',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 30,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 34, 'end': 40, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': 'show me a list of ground transportation at denver',
#   'intent': 'ground_service',
#   'entities': [{'start': 43,
#     'end': 49,
#     'value': 'denver',
#     'entity': 'city_name'}]},
#  {'text': "i 'd like a flight from columbus to phoenix stopping in cincinnati and serving dinner what 's available",
#   'intent': 'flight',
#   'entities': [{'start': 24,
#     'end': 32,
#     'value': 'columbus',
#     'entity': 'fromloc.city_name'},
#    {'start': 36, 'end': 43, 'value': 'phoenix', 'entity': 'toloc.city_name'},
#    {'start': 56,
#     'end': 66,
#     'value': 'cincinnati',
#     'entity': 'stoploc.city_name'},
#    {'start': 79, 'end': 85, 'value': 'dinner', 'entity': 'meal_description'}]},
#  {'text': 'also show me flights from san francisco to pittsburgh on tuesday',
#   'intent': 'flight',
#   'entities': [{'start': 26,
#     'end': 39,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 43,
#     'end': 53,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 57,
#     'end': 64,
#     'value': 'tuesday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'show flights from dallas to oakland',
#   'intent': 'flight',
#   'entities': [{'start': 18,
#     'end': 24,
#     'value': 'dallas',
#     'entity': 'fromloc.city_name'},
#    {'start': 28, 'end': 35, 'value': 'oakland', 'entity': 'toloc.city_name'}]},
#  {'text': 'give me the cheapest flight from charlotte to long beach',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'cheapest',
#     'entity': 'cost_relative'},
#    {'start': 33,
#     'end': 42,
#     'value': 'charlotte',
#     'entity': 'fromloc.city_name'},
#    {'start': 46,
#     'end': 56,
#     'value': 'long beach',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'show me all flights from san francisco to pittsburgh',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 38,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 42,
#     'end': 52,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'find me a flight on united from boston to san francisco with a stopover in denver',
#   'intent': 'flight',
#   'entities': [{'start': 20,
#     'end': 26,
#     'value': 'united',
#     'entity': 'airline_name'},
#    {'start': 32, 'end': 38, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 42,
#     'end': 55,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 75,
#     'end': 81,
#     'value': 'denver',
#     'entity': 'stoploc.city_name'}]},
#  {'text': 'show me the last flight from love field',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 16,
#     'value': 'last',
#     'entity': 'flight_mod'},
#    {'start': 29,
#     'end': 39,
#     'value': 'love field',
#     'entity': 'fromloc.airport_name'}]},
#  {'text': 'what flights go from newark to boston after 5 pm',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'newark',
#     'entity': 'fromloc.city_name'},
#    {'start': 31, 'end': 37, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 38,
#     'end': 43,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 44, 'end': 48, 'value': '5 pm', 'entity': 'depart_time.time'}]},
#  {'text': 'what are all the flights from boston to dallas',
#   'intent': 'flight',
#   'entities': [{'start': 30,
#     'end': 36,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 40, 'end': 46, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': 'what is the earliest flight departing san francisco and arriving in boston on november ninth',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'earliest',
#     'entity': 'flight_mod'},
#    {'start': 38,
#     'end': 51,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 68, 'end': 74, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 78,
#     'end': 86,
#     'value': 'november',
#     'entity': 'arrive_date.month_name'},
#    {'start': 87,
#     'end': 92,
#     'value': 'ninth',
#     'entity': 'arrive_date.day_number'}]},
#  {'text': 'what is the earliest flight flying from pittsburgh to atlanta on july fifth',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'earliest',
#     'entity': 'flight_mod'},
#    {'start': 40,
#     'end': 50,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 54, 'end': 61, 'value': 'atlanta', 'entity': 'toloc.city_name'},
#    {'start': 65,
#     'end': 69,
#     'value': 'july',
#     'entity': 'depart_date.month_name'},
#    {'start': 70,
#     'end': 75,
#     'value': 'fifth',
#     'entity': 'depart_date.day_number'}]},
#  {'text': 'please list available flights for next saturday from philadelphia to dallas',
#   'intent': 'flight',
#   'entities': [{'start': 34,
#     'end': 38,
#     'value': 'next',
#     'entity': 'depart_date.date_relative'},
#    {'start': 39,
#     'end': 47,
#     'value': 'saturday',
#     'entity': 'depart_date.day_name'},
#    {'start': 53,
#     'end': 65,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 69, 'end': 75, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': 'what flights leave pittsburgh and arrive in los angeles after 5 pm on thursday',
#   'intent': 'flight',
#   'entities': [{'start': 19,
#     'end': 29,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 44,
#     'end': 55,
#     'value': 'los angeles',
#     'entity': 'toloc.city_name'},
#    {'start': 56,
#     'end': 61,
#     'value': 'after',
#     'entity': 'arrive_time.time_relative'},
#    {'start': 62, 'end': 66, 'value': '5 pm', 'entity': 'arrive_time.time'},
#    {'start': 70,
#     'end': 78,
#     'value': 'thursday',
#     'entity': 'arrive_date.day_name'}]},
#  {'text': 'what is the transportation time from the airport to boston',
#   'intent': 'ground_service',
#   'entities': [{'start': 27, 'end': 31, 'value': 'time', 'entity': 'time'},
#    {'start': 52, 'end': 58, 'value': 'boston', 'entity': 'toloc.city_name'}]},
#  {'text': 'which airline has the smallest plane leaving pittsburgh and arriving in baltimore on july fourth',
#   'intent': 'airline',
#   'entities': [{'start': 22, 'end': 30, 'value': 'smallest', 'entity': 'mod'},
#    {'start': 45,
#     'end': 55,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 72, 'end': 81, 'value': 'baltimore', 'entity': 'toloc.city_name'},
#    {'start': 85,
#     'end': 89,
#     'value': 'july',
#     'entity': 'arrive_date.month_name'},
#    {'start': 90,
#     'end': 96,
#     'value': 'fourth',
#     'entity': 'arrive_date.day_number'}]},
# ...
#   'intent': 'flight',
#   'entities': [{'start': 31,
#     'end': 38,
#     'value': 'oakland',
#     'entity': 'fromloc.city_name'},
#    {'start': 42, 'end': 48, 'value': 'denver', 'entity': 'toloc.city_name'},
#    {'start': 68,
#     'end': 85,
#     'value': 'dallas fort worth',
#     'entity': 'stoploc.city_name'}]},
#  {'text': 'show me first class airlines from san francisco to pittsburgh on next tuesday first class only',
#   'intent': 'airline',
#   'entities': [{'start': 8,
#     'end': 19,
#     'value': 'first class',
#     'entity': 'class_type'},
#    {'start': 34,
#     'end': 47,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 51,
#     'end': 61,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'},
#    {'start': 65,
#     'end': 69,
#     'value': 'next',
#     'entity': 'depart_date.date_relative'},
#    {'start': 70,
#     'end': 77,
#     'value': 'tuesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 78, 'end': 89, 'value': 'first class', 'entity': 'class_type'}]},
#  {'text': 'what flights are there on saturdays from philadelphia to denver',
#   'intent': 'flight',
#   'entities': [{'start': 26,
#     'end': 35,
#     'value': 'saturdays',
#     'entity': 'depart_date.day_name'},
#    {'start': 41,
#     'end': 53,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 57, 'end': 63, 'value': 'denver', 'entity': 'toloc.city_name'}]},
#  {'text': 'i need a flight from denver to washington dc on wednesday',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 27,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 31,
#     'end': 41,
#     'value': 'washington',
#     'entity': 'toloc.city_name'},
#    {'start': 42, 'end': 44, 'value': 'dc', 'entity': 'toloc.state_code'},
#    {'start': 48,
#     'end': 57,
#     'value': 'wednesday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'show me the flights from columbus to charlotte',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 33,
#     'value': 'columbus',
#     'entity': 'fromloc.city_name'},
#    {'start': 37,
#     'end': 46,
#     'value': 'charlotte',
#     'entity': 'toloc.city_name'}]},
#  {'text': "oh let 's see does eastern airline have a flight from atlanta to washington",
#   'intent': 'flight',
#   'entities': [{'start': 19,
#     'end': 34,
#     'value': 'eastern airline',
#     'entity': 'airline_name'},
#    {'start': 54, 'end': 61, 'value': 'atlanta', 'entity': 'fromloc.city_name'},
#    {'start': 65,
#     'end': 75,
#     'value': 'washington',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what is the price of business class from boston to san francisco on twa',
#   'intent': 'airfare',
#   'entities': [{'start': 21,
#     'end': 35,
#     'value': 'business class',
#     'entity': 'class_type'},
#    {'start': 41, 'end': 47, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 51,
#     'end': 64,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 68, 'end': 71, 'value': 'twa', 'entity': 'airline_code'}]},
#  {'text': 'flights from atlanta to dallas in the afternoon',
#   'intent': 'flight',
#   'entities': [{'start': 13,
#     'end': 20,
#     'value': 'atlanta',
#     'entity': 'fromloc.city_name'},
#    {'start': 24, 'end': 30, 'value': 'dallas', 'entity': 'toloc.city_name'},
#    {'start': 38,
#     'end': 47,
#     'value': 'afternoon',
#     'entity': 'depart_time.period_of_day'}]},
#  {'text': 'eastern flight 825 from atlanta to denver leaving at 555 what type of aircraft is used on that flight',
#   'intent': 'flight',
#   'entities': [{'start': 1,
#     'end': 8,
#     'value': 'eastern',
#     'entity': 'airline_name'},
#    {'start': 15, 'end': 18, 'value': '825', 'entity': 'flight_number'},
#    {'start': 24, 'end': 31, 'value': 'atlanta', 'entity': 'fromloc.city_name'},
#    {'start': 35, 'end': 41, 'value': 'denver', 'entity': 'toloc.city_name'},
#    {'start': 53, 'end': 56, 'value': '555', 'entity': 'depart_time.time'}]},
#  {'text': 'what are all the flights between san francisco and boston',
#   'intent': 'flight',
#   'entities': [{'start': 33,
#     'end': 46,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 51, 'end': 57, 'value': 'boston', 'entity': 'toloc.city_name'}]},
#  {'text': 'define airline us',
#   'intent': 'abbreviation',
#   'entities': [{'start': 15,
#     'end': 17,
#     'value': 'us',
#     'entity': 'airline_code'}]},
#  {'text': 'i want to fly philadelphia to san francisco on july eighth',
#   'intent': 'flight',
#   'entities': [{'start': 14,
#     'end': 26,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 30,
#     'end': 43,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 47,
#     'end': 51,
#     'value': 'july',
#     'entity': 'depart_date.month_name'},
#    {'start': 52,
#     'end': 58,
#     'value': 'eighth',
#     'entity': 'depart_date.day_number'}]},
#  {'text': 'find a flight from boston to washington on monday',
#   'intent': 'flight',
#   'entities': [{'start': 19,
#     'end': 25,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 29,
#     'end': 39,
#     'value': 'washington',
#     'entity': 'toloc.city_name'},
#    {'start': 43,
#     'end': 49,
#     'value': 'monday',
#     'entity': 'depart_date.day_name'}]},
#  {'text': 'give me information on flights from atlanta to washington dc on wednesday after 4 pm and thursday before 9 am',
#   'intent': 'flight',
#   'entities': [{'start': 36,
#     'end': 43,
#     'value': 'atlanta',
#     'entity': 'fromloc.city_name'},
#    {'start': 47,
#     'end': 57,
#     'value': 'washington',
#     'entity': 'toloc.city_name'},
#    {'start': 58, 'end': 60, 'value': 'dc', 'entity': 'toloc.state_code'},
#    {'start': 64,
#     'end': 73,
#     'value': 'wednesday',
#     'entity': 'depart_date.day_name'},
#    {'start': 74,
#     'end': 79,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 80, 'end': 84, 'value': '4 pm', 'entity': 'depart_time.time'},
#    {'start': 89,
#     'end': 97,
#     'value': 'thursday',
#     'entity': 'depart_date.day_name'},
#    {'start': 98,
#     'end': 104,
#     'value': 'before',
#     'entity': 'depart_time.time_relative'},
#    {'start': 105, 'end': 109, 'value': '9 am', 'entity': 'depart_time.time'}]},
#  {'text': 'find the flights from boston to san francisco leaving after 6 pm',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 28,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 32,
#     'end': 45,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 54,
#     'end': 59,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 60, 'end': 64, 'value': '6 pm', 'entity': 'depart_time.time'}]},
#  {'text': 'show me the cheapest fare from dallas to baltimore',
#   'intent': 'airfare',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'cheapest',
#     'entity': 'cost_relative'},
#    {'start': 31, 'end': 37, 'value': 'dallas', 'entity': 'fromloc.city_name'},
#    {'start': 41,
#     'end': 50,
#     'value': 'baltimore',
#     'entity': 'toloc.city_name'}]},
#  {'text': "i live in denver and i 'd like to make a trip to pittsburgh",
#   'intent': 'flight',
#   'entities': [{'start': 10,
#     'end': 16,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 49,
#     'end': 59,
#     'value': 'pittsburgh',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'give me flights that arrive in baltimore from atlanta denver and pittsburgh',
#   'intent': 'flight',
#   'entities': [{'start': 31,
#     'end': 40,
#     'value': 'baltimore',
#     'entity': 'toloc.city_name'},
#    {'start': 46, 'end': 53, 'value': 'atlanta', 'entity': 'fromloc.city_name'},
#    {'start': 54, 'end': 60, 'value': 'denver', 'entity': 'fromloc.city_name'},
#    {'start': 65,
#     'end': 75,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'}]},
#  {'text': "hello i 'm trying to find a flight that goes from pittsburgh to denver after 2 pm",
#   'intent': 'flight',
#   'entities': [{'start': 50,
#     'end': 60,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 64, 'end': 70, 'value': 'denver', 'entity': 'toloc.city_name'},
#    {'start': 71,
#     'end': 76,
#     'value': 'after',
#     'entity': 'depart_time.time_relative'},
#    {'start': 77, 'end': 81, 'value': '2 pm', 'entity': 'depart_time.time'}]},
#  {'text': 'what airlines fly between boston and san francisco',
#   'intent': 'airline',
#   'entities': [{'start': 26,
#     'end': 32,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 37,
#     'end': 50,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'code ff',
#   'intent': 'abbreviation',
#   'entities': [{'start': 5,
#     'end': 7,
#     'value': 'ff',
#     'entity': 'airline_code'}]},
#  {'text': 'what is the earliest flight from boston to san francisco on november seventh',
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 20,
#     'value': 'earliest',
#     'entity': 'flight_mod'},
#    {'start': 33, 'end': 39, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 43,
#     'end': 56,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 60,
#     'end': 68,
#     'value': 'november',
#     'entity': 'depart_date.month_name'},
#    {'start': 69,
#     'end': 76,
#     'value': 'seventh',
#     'entity': 'depart_date.day_number'}]},
#  {'text': 'list all flights from boston to san francisco on us air',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 28,
#     'value': 'boston',
#     'entity': 'fromloc.city_name'},
#    {'start': 32,
#     'end': 45,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 49, 'end': 55, 'value': 'us air', 'entity': 'airline_name'}]},
#  {'text': 'i would like a list of flights from pittsburgh to dallas',
#   'intent': 'flight',
#   'entities': [{'start': 36,
#     'end': 46,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 50, 'end': 56, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': "on november twenty third of this year 1991 i 'd like to fly from atlanta to denver and i 'd like to fly on delta",
#   'intent': 'flight',
#   'entities': [{'start': 3,
#     'end': 11,
#     'value': 'november',
#     'entity': 'depart_date.month_name'},
#    {'start': 12,
#     'end': 24,
#     'value': 'twenty third',
#     'entity': 'depart_date.day_number'},
#    {'start': 33, 'end': 37, 'value': 'year', 'entity': 'depart_date.year'},
#    {'start': 65, 'end': 72, 'value': 'atlanta', 'entity': 'fromloc.city_name'},
#    {'start': 76, 'end': 82, 'value': 'denver', 'entity': 'toloc.city_name'},
#    {'start': 107, 'end': 112, 'value': 'delta', 'entity': 'airline_name'}]},
#  {'text': 'do you have any airlines that would stop at denver on the way from baltimore to san francisco',
#   'intent': 'airline',
#   'entities': [{'start': 44,
#     'end': 50,
#     'value': 'denver',
#     'entity': 'stoploc.city_name'},
#    {'start': 67,
#     'end': 76,
#     'value': 'baltimore',
#     'entity': 'fromloc.city_name'},
#    {'start': 80,
#     'end': 93,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'list all flights from tampa florida to miami that are the cheapest one way',
#   'intent': 'flight',
#   'entities': [{'start': 22,
#     'end': 27,
#     'value': 'tampa',
#     'entity': 'fromloc.city_name'},
#    {'start': 28,
#     'end': 35,
#     'value': 'florida',
#     'entity': 'fromloc.state_name'},
#    {'start': 39, 'end': 44, 'value': 'miami', 'entity': 'toloc.city_name'},
#    {'start': 58, 'end': 66, 'value': 'cheapest', 'entity': 'cost_relative'},
#    {'start': 67, 'end': 74, 'value': 'one way', 'entity': 'round_trip'}]},
#  {'text': 'list the nonstop flights on wednesday june second from miami to baltimore arriving in baltimore between 1115 am and 1245 pm',
#   'intent': 'flight',
#   'entities': [{'start': 9,
#     'end': 16,
#     'value': 'nonstop',
#     'entity': 'flight_stop'},
#    {'start': 28,
#     'end': 37,
#     'value': 'wednesday',
#     'entity': 'arrive_date.day_name'},
#    {'start': 38,
#     'end': 42,
#     'value': 'june',
#     'entity': 'arrive_date.month_name'},
#    {'start': 43,
#     'end': 49,
#     'value': 'second',
#     'entity': 'arrive_date.day_number'},
#    {'start': 55, 'end': 60, 'value': 'miami', 'entity': 'fromloc.city_name'},
#    {'start': 64, 'end': 73, 'value': 'baltimore', 'entity': 'toloc.city_name'},
#    {'start': 86, 'end': 95, 'value': 'baltimore', 'entity': 'toloc.city_name'},
#    {'start': 104,
#     'end': 111,
#     'value': '1115 am',
#     'entity': 'arrive_time.start_time'},
#    {'start': 116,
#     'end': 123,
#     'value': '1245 pm',
#     'entity': 'arrive_time.end_time'}]},
#  {'text': 'give me flights from san francisco to boston on thursday afternoon',
#   'intent': 'flight',
#   'entities': [{'start': 21,
#     'end': 34,
#     'value': 'san francisco',
#     'entity': 'fromloc.city_name'},
#    {'start': 38, 'end': 44, 'value': 'boston', 'entity': 'toloc.city_name'},
#    {'start': 48,
#     'end': 56,
#     'value': 'thursday',
#     'entity': 'depart_date.day_name'},
#    {'start': 57,
#     'end': 66,
#     'value': 'afternoon',
#     'entity': 'depart_time.period_of_day'}]},
#  {'text': 'denver to atlanta',
#   'intent': 'flight',
#   'entities': [{'start': 1,
#     'end': 7,
#     'value': 'denver',
#     'entity': 'fromloc.city_name'},
#    {'start': 10, 'end': 17, 'value': 'atlanta', 'entity': 'toloc.city_name'}]},
#  {'text': "what 's the last flight leaving from pittsburgh to oakland",
#   'intent': 'flight',
#   'entities': [{'start': 12,
#     'end': 16,
#     'value': 'last',
#     'entity': 'flight_mod'},
#    {'start': 37,
#     'end': 47,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 51, 'end': 58, 'value': 'oakland', 'entity': 'toloc.city_name'}]},
#  {'text': 'does any airline have an afternoon flight from boston to oakland',
#   'intent': 'airline',
#   'entities': [{'start': 25,
#     'end': 34,
#     'value': 'afternoon',
#     'entity': 'depart_time.period_of_day'},
#    {'start': 47, 'end': 53, 'value': 'boston', 'entity': 'fromloc.city_name'},
#    {'start': 57, 'end': 64, 'value': 'oakland', 'entity': 'toloc.city_name'}]},
#  {'text': 'do you have a flight from philadelphia to san francisco with a stopover in dallas',
#   'intent': 'flight',
#   'entities': [{'start': 26,
#     'end': 38,
#     'value': 'philadelphia',
#     'entity': 'fromloc.city_name'},
#    {'start': 42,
#     'end': 55,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'},
#    {'start': 75,
#     'end': 81,
#     'value': 'dallas',
#     'entity': 'stoploc.city_name'}]},
#  {'text': 'i want to make a trip from washington to san francisco',
#   'intent': 'flight',
#   'entities': [{'start': 27,
#     'end': 37,
#     'value': 'washington',
#     'entity': 'fromloc.city_name'},
#    {'start': 41,
#     'end': 54,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'i would like information on flights leaving atlanta in the afternoon arriving in dallas',
#   'intent': 'flight',
#   'entities': [{'start': 44,
#     'end': 51,
#     'value': 'atlanta',
#     'entity': 'fromloc.city_name'},
#    {'start': 59,
#     'end': 68,
#     'value': 'afternoon',
#     'entity': 'depart_time.period_of_day'},
#    {'start': 81, 'end': 87, 'value': 'dallas', 'entity': 'toloc.city_name'}]},
#  {'text': 'show me all flights from san diego to new york nonstop',
#   'intent': 'flight',
#   'entities': [{'start': 25,
#     'end': 34,
#     'value': 'san diego',
#     'entity': 'fromloc.city_name'},
#    {'start': 38, 'end': 46, 'value': 'new york', 'entity': 'toloc.city_name'},
#    {'start': 47, 'end': 54, 'value': 'nonstop', 'entity': 'flight_stop'}]},
#  {'text': 'show me all flights with fares from pittsburgh to san francisco',
#   'intent': 'flight',
#   'entities': [{'start': 36,
#     'end': 46,
#     'value': 'pittsburgh',
#     'entity': 'fromloc.city_name'},
#    {'start': 50,
#     'end': 63,
#     'value': 'san francisco',
#     'entity': 'toloc.city_name'}]},
#  {'text': 'what are the flights from milwaukee to tampa',
#   'intent': 'flight',
#   'entities': [{'start': 26,
#     'end': 35,
#     'value': 'milwaukee',
#     'entity': 'fromloc.city_name'},
#    {'start': 39, 'end': 44, 'value': 'tampa', 'entity': 'toloc.city_name'}]},
#  ...]

# %%
df = pd.DataFrame()
df["text"] = np.array([sample['text'] for sample in data['rasa_nlu_data']['common_examples']])
df["intent"] = np.array([sample['intent'] for sample in data['rasa_nlu_data']['common_examples']])
df["entities"] = np.array([sample['entities'] for sample in data['rasa_nlu_data']['common_examples']])

# %%
def sep(x):
    if x.find('+') != -1:
        return x.split('+')
    else:
        return x
df['intent'] = df['intent'].map(lambda x: sep(x))

# %%
multi_intents = [i for i in df['intent'] if type(i) == list]

# %% [markdown]
# ## 1. Document Pooling embedding

# %%
from flair.embeddings import WordEmbeddings, FlairEmbeddings, DocumentPoolEmbeddings, Sentence

# initialize the word embeddings
glove_embedding = WordEmbeddings('glove')
flair_embedding_forward = FlairEmbeddings('news-forward')
flair_embedding_backward = FlairEmbeddings('news-backward')

# initialize the document embeddings, mode = mean
document_embeddings = DocumentPoolEmbeddings([glove_embedding,
                                              flair_embedding_backward,
                                              flair_embedding_forward])
# Out:
# 2019-09-30 22:28:30,102 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings/glove.gensim.vectors.npy not found in cache, downloading to /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmpjhq_2uj0
# 100%|██████████| 160000128/160000128 [00:11<00:00, 13743566.33B/s]
# 2019-09-30 22:28:42,453 copying /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmpjhq_2uj0 to cache at /Users/waynewu/.flair/embeddings/glove.gensim.vectors.npy
# 2019-09-30 22:28:43,039 removing temp file /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmpjhq_2uj0
# 2019-09-30 22:28:43,578 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings/glove.gensim not found in cache, downloading to /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmptwcn30ye
# 100%|██████████| 21494764/21494764 [00:06<00:00, 3345051.90B/s]
# 2019-09-30 22:28:50,648 copying /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmptwcn30ye to cache at /Users/waynewu/.flair/embeddings/glove.gensim
# 2019-09-30 22:28:50,696 removing temp file /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmptwcn30ye
# 2019-09-30 22:28:52,723 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings-v0.4.1/big-news-forward--h2048-l1-d0.05-lr30-0.25-20/news-forward-0.4.1.pt not found in cache, downloading to /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmpm5eka57p
# 100%|██████████| 73034624/73034624 [00:06<00:00, 10579432.53B/s]
# 2019-09-30 22:29:00,215 copying /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmpm5eka57p to cache at /Users/waynewu/.flair/embeddings/news-forward-0.4.1.pt
# 2019-09-30 22:29:00,369 removing temp file /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmpm5eka57p
# 2019-09-30 22:29:01,324 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings-v0.4.1/big-news-backward--h2048-l1-d0.05-lr30-0.25-20/news-backward-0.4.1.pt not found in cache, downloading to /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmp8ez4a8b3
# 100%|██████████| 73034575/73034575 [00:06<00:00, 10789968.03B/s]
# 2019-09-30 22:29:08,856 copying /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmp8ez4a8b3 to cache at /Users/waynewu/.flair/embeddings/news-backward-0.4.1.pt
# 2019-09-30 22:29:09,103 removing temp file /var/folders/79/8vg87rnd3rj6bg7rtfq66cvr0000gn/T/tmp8ez4a8b3

# %%
for i in range(len(df['intent'])):
    
    sentence = Sentence(df.loc[i]['intent'])
    
    # embed the sentence with our document embedding
    document_embeddings.embed(sentence)

    # now check out the embedded sentence.
    df.loc[i]['embeddings'] = sentence.get_embedding()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-eaebd6bd9cae> in <module>()
#       4
#       5     # embed the sentence with our document embedding
# ----> 6     document_embeddings.embed(sentence)
#       7
#       8     # now check out the embedded sentence.
#
# /anaconda3/lib/python3.6/site-packages/flair/embeddings.py in embed(self, sentences)
#    2558             sentences = [sentences]
#    2559
# -> 2560         self.embeddings.embed(sentences)
#    2561
#    2562         for sentence in sentences:
#
# /anaconda3/lib/python3.6/site-packages/flair/embeddings.py in embed(self, sentences, static_embeddings)
#     147
#     148         for embedding in self.embeddings:
# --> 149             embedding.embed(sentences)
#     150
#     151     @property
#
# /anaconda3/lib/python3.6/site-packages/flair/embeddings.py in embed(self, sentences)
#      79
#      80         if not everything_embedded or not self.static_embeddings:
# ---> 81             self._add_embeddings_internal(sentences)
#      82
#      83         return sentences
#
# /anaconda3/lib/python3.6/site-packages/flair/embeddings.py in _add_embeddings_internal(self, sentences)
#    1820             # get hidden states from language model
#    1821             all_hidden_states_in_lm = self.lm.get_representation(
# -> 1822                 sentences_padded, self.chars_per_chunk
#    1823             )
#    1824
#
# /anaconda3/lib/python3.6/site-packages/flair/models/language_model.py in get_representation(self, strings, chars_per_chunk)
#     129             ).transpose(0, 1)
#     130
# --> 131             prediction, rnn_output, hidden = self.forward(batch, hidden)
#     132
#     133             output_parts.append(rnn_output)
#
# /anaconda3/lib/python3.6/site-packages/flair/models/language_model.py in forward(self, input, hidden, ordered_sequence_lengths)
#      76         self.rnn.flatten_parameters()
#      77
# ---> 78         output, hidden = self.rnn(emb, hidden)
#      79
#      80         if self.proj is not None:
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     557             return self.forward_packed(input, hx)
#     558         else:
# --> 559             return self.forward_tensor(input, hx)
#     560
#     561
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     537         unsorted_indices = None
#     538
# --> 539         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     540
#     541         return output, self.permute_hidden(hidden, unsorted_indices)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     520         if batch_sizes is None:
#     521             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 522                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     523         else:
#     524             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=40)
km.fit(BERT_corpus)
clusters = km.labels_.tolist()

# %% [markdown]
# ## 2. RNN embedding

# %% [markdown]
# ## 3. BERT embeddings

# %%
from bert_serving.client import BertClient
from sklearn.cluster import KMeans

bc = BertClient()
BERT_embedding = bc.encode(text_list)

km = KMeans(n_clusters=40)
km.fit(BERT_corpus)
clusters = km.labels_.tolist()
